# %% [markdown]
# ### Let's clean bedsheets.csv

# %% [markdown]
# ### Let me load it first

# %%
import pandas as pd

# %%
bedSheetsData = pd.read_csv('/Users/negikshitiz/Documents/CelebalTech/Dataset/bedsheets.csv')

# %% [markdown]
# ### Now that i've loaded it let's explore it.

# %%
bedSheetsData.head
bedSheetsData.tail
# Out:
# <bound method NDFrame.tail of     product_id          title  \
# 0     18602872        My Room
# 1     18602850        My Room
# 2      8961147     Story@home
# 3      8430275      MYTRIDENT
# 4     18346118         Arrabi
# 5     18327434     BELLA CASA
# 6     18492504          ROMEE
# 7     13729978         DDecor
# 8     19788630   Home Ecstasy
# 9     20296382  DREAM WEAVERZ
# 10    18346134         Arrabi
#
#                                   product_description  rating  ratings_count  \
# 0   Yellow & Green Floral 140 TC King Bedsheet wit...     4.7             10
# 1   Ethnic Print 144 TC Super King Bedsheet with 2...     4.5             22
# 2   Pink & White Floral 160 TC Cotton 1 King Bedsh...     3.7              7
# 3   Sea Green Floral Flat 120 TC Cotton 1 Queen Be...     4.4             26
# 4   Pink & White Graphic 300 TC King Bedsheet with...     0.0              0
# 5                               Unisex Blue Bedsheets     0.0              0
# ...

# %% [markdown]
# ### Shape of dataset

# %%
print(bedSheetsData.shape)
# Out:
# (11, 24)

# %% [markdown]
# ### What about column name?

# %%
print(bedSheetsData.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %% [markdown]
# ### What about their dataTypes

# %%
print(bedSheetsData.dtypes)
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said       float64
# seller_name                   str
# sizes                         str
# videos                    float64
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %% [markdown]
# ### Let's see missing values

# %%
missingWhere = bedSheetsData.isnull()
print(missingWhere)
# Out:
#     product_id  title  product_description  rating  ratings_count  \
# 0        False  False                False   False          False
# 1        False  False                False   False          False
# 2        False  False                False   False          False
# 3        False  False                False   False          False
# 4        False  False                False   False          False
# 5        False  False                False   False          False
# 6        False  False                False   False          False
# 7        False  False                False   False          False
# 8        False  False                False   False          False
# 9        False  False                False   False          False
# 10       False  False                False   False          False
#
#     initial_price  discount  final_price  currency  images  ...  \
# 0           False     False        False     False   False  ...
# ...

# %% [markdown]
# ### Let's see count of null values per column

# %%
bedSheetsData.isnull().sum()
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   0
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said       11
# seller_name                9
# sizes                      0
# videos                    11
# seller_information         9
# variations                 0
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %% [markdown]
# ### Let's see if their are duplicate values

# %%
bedSheetsData.drop_duplicates(subset=["product_id"], inplace=True)

# %% [markdown]
# ### We can see that 'what_customers_said', 'videos', and 'seller_information' have mostly null values so lets drop em

# %%
bedSheetsData = bedSheetsData.drop({'what_customers_said', 'seller_information', 'videos'}, axis=1)

# %%
print(bedSheetsData.to_string())
# Out:
#     product_id          title                                                           product_description  rating  ratings_count  initial_price  discount  final_price currency                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %% [markdown]
# ### oh i forgot to drop sellerName it's mostly null

# %%
bedSheetsData.drop('seller_name', axis=1)
# Out:
#     product_id          title  \
# 0     18602872        My Room
# 1     18602850        My Room
# 2      8961147     Story@home
# 3      8430275      MYTRIDENT
# 4     18346118         Arrabi
# 5     18327434     BELLA CASA
# 6     18492504          ROMEE
# 7     13729978         DDecor
# 8     19788630   Home Ecstasy
# 9     20296382  DREAM WEAVERZ
# 10    18346134         Arrabi
#
#                                   product_description  rating  ratings_count  \
# 0   Yellow & Green Floral 140 TC King Bedsheet wit...     4.7             10
# 1   Ethnic Print 144 TC Super King Bedsheet with 2...     4.5             22
# 2   Pink & White Floral 160 TC Cotton 1 King Bedsh...     3.7              7
# 3   Sea Green Floral Flat 120 TC Cotton 1 Queen Be...     4.4             26
# 4   Pink & White Graphic 300 TC King Bedsheet with...     0.0              0
# 5                               Unisex Blue Bedsheets     0.0              0
# ...

# %% [markdown]
# ### Let's go with the some operations that i can perform on the dataset

# %%
highRating = bedSheetsData[bedSheetsData["rating"] >= 3.5]
highRating.head()
# Out:
#    product_id       title                                product_description  \
# 0    18602872     My Room  Yellow & Green Floral 140 TC King Bedsheet wit...
# 1    18602850     My Room  Ethnic Print 144 TC Super King Bedsheet with 2...
# 2     8961147  Story@home  Pink & White Floral 160 TC Cotton 1 King Bedsh...
# 3     8430275   MYTRIDENT  Sea Green Floral Flat 120 TC Cotton 1 Queen Be...
# 6    18492504       ROMEE  Blue & Beige Conversational 160 TC King Bedshe...
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     4.7             10         2999.0      54.0  "₹2,999.00"      INR
# 1     4.5             22         2999.0      54.0  "₹2,999.00"      INR
# 2     3.7              7         2199.0      53.0  "₹2,199.00"      INR
# 3     4.4             26         2199.0      46.0  "₹2,199.00"      INR
# 6     3.9             10         3499.0      65.0  "₹3,499.00"      INR
#
#                                               images  ...  \
# ...

# %%
result = bedSheetsData.loc[
    bedSheetsData["rating"] >= 4.0,
    ["title", "rating", "final_price"]
]
print(result.head())
# Out:
#            title  rating  final_price
# 0        My Room     4.7  "₹2,999.00"
# 1        My Room     4.5  "₹2,999.00"
# 3      MYTRIDENT     4.4  "₹2,199.00"
# 8   Home Ecstasy     4.5  "₹1,199.00"
# 10        Arrabi     4.3  "₹6,329.00"
